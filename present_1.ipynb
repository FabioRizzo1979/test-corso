# %%
# !pip install yfinance requests beautifulsoup4 lxml plotly pandas
# Out:
# Requirement already satisfied: yfinance in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.2.0)
# Requirement already satisfied: requests in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (4.14.3)
# Requirement already satisfied: lxml in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (5.3.1)
# Requirement already satisfied: plotly in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (6.5.2)
# Requirement already satisfied: pandas in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: multitasking>=0.0.7 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: pytz>=2022.5 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (3.19.0)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (6.33.5)
# Requirement already satisfied: websockets>=13.0 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: cffi>=1.12.0 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2025.1.31)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from beautifulsoup4) (4.12.2)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly) (2.16.0)
# Requirement already satisfied: packaging in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: pycparser in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in C:\Users\rizzo.ESI-DOM\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import yfinance as yf
import pandas as pd
import requests
from bs4 import BeautifulSoup
import plotly.graph_objects as go

# %%
tesla = yf.Ticker("TSLA")
tesla_data = tesla.history(period="max")

tesla_data.reset_index(inplace=True)
tesla_data.head()
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %%
tesla_revenue["Revenue"] = tesla_revenue["Revenue"].str.replace("$","", regex=False).str.replace(",","", regex=False)

tesla_revenue.dropna(inplace=True)
tesla_revenue = tesla_revenue[tesla_revenue["Revenue"] != ""]

tesla_revenue["Revenue"] = pd.to_numeric(tesla_revenue["Revenue"])

tesla_revenue.tail()
# Out:
#           Date  Revenue
# 55  2012-03-31       30
# 56  2011-12-31       39
# 57  2011-09-30       58
# 58  2011-06-30       58
# 59  2011-03-31       49
