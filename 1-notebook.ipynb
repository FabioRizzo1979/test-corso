# %% [markdown]
# # test

# %% [markdown]
# # intraduzione de test

# %% [markdown]
# # Linguaggi della Scienza dei Dati
#
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# # Librerie di Scienza dei Dati
#
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - TensorFlow
# - Keras
# - PyTorch

# %% [markdown]
# # Tabella degli Strumenti di Data Science
#
# | Strumento        | Descrizione                        |
# |------------------|-------------------------------------|
# | RStudio          | IDE per linguaggio R               |
# | Jupyter Notebook | Ambiente interattivo per Python e R|
# | VS Code          | Editor di codice multi-linguaggio  |
# | Spyder           | IDE per Python orientato ai dati   |
# | Tableau          | Visualizzazione e BI               |

# %% [markdown]
# # Esempi di Espressioni Aritmetiche
#
# In questa sezione mostriamo alcuni esempi di espressioni aritmetiche di base utilizzando Python.

# %%
# Esempio di moltiplicazione e addizione

# Moltiplicazione
moltiplicazione = 5 * 3
print("Risultato moltiplicazione:", moltiplicazione)

# Addizione
addizione = 10 + 7
print("Risultato addizione:", addizione)

# %%
# Conversione minuti in ore

minuti = 150
ore = minuti / 60
print(minuti, "minuti equivalgono a", ore, "ore")

# %% [markdown]
# # Obiettivi del Corso
#
# - Imparare i concetti base di Python
# - Conoscere gli strumenti della Data Science
# - Saper utilizzare Jupyter Notebook
# - Applicare operazioni matematiche e di manipolazione dati

# %% [markdown]
# # Autore
#
# **Fabio Rizzo**
